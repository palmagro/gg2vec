# %%
# %load_ext autoreload
# %autoreload 1
from node2vec import *
from experiment import *
from composite_experiment import *
from tabulate import tabulate
output_notebook()
import warnings
warnings.filterwarnings("ignore")
sys.setrecursionlimit(100000)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="64e88cef-2c56-421f-881c-fd2dddb234d7">Loading BokehJS ...</span>
#     </div>

# %%
from theano import function, config, shared, tensor, sandbox
import numpy
import time

vlen = 10 * 30 * 768  # 10 x #cores x # threads per core
iters = 1000

rng = numpy.random.RandomState(22)
x = shared(numpy.asarray(rng.rand(vlen), config.floatX))
f = function([], tensor.exp(x))
print(f.maker.fgraph.toposort())
t0 = time.time()
for i in range(iters):
    r = f()
t1 = time.time()
print("Looping %d times took %f seconds" % (iters, t1 - t0))
print("Result is %s" % (r,))
if numpy.any([isinstance(x.op, tensor.Elemwise) and
              ('Gpu' not in type(x.op).__name__)
              for x in f.maker.fgraph.toposort()]):
    print('Used the cpu')
else:
    print('Used the gpu')

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"k",0.5,10)
e.ntype_prediction(1,20,2,False)
show(e.p)
# Out:
#     <div class="plotdiv" id="a0134d83-5bce-4e48-9a44-99eb82cad37c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"]],"SVM",5,10)
e.ntype_prediction(1,4,5,False)
show(e.p)
# Out:
#     <div class="plotdiv" id="5c7b4f9f-5860-4ffc-aff9-44fad8181cbe"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"RF",5,10)
e.ntype_prediction(1,10,10,False)
show(e.p)
# Out:
#     <div class="plotdiv" id="290bb5f3-2254-4bd5-8d9d-dfed9735d7a0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"k",0.5,10)
e.ltype_prediction(1,6,2,False)
show(e.p)
# Out:
#     <div class="plotdiv" id="2f2f6760-6d81-4318-a3f2-dc4bcd72b6fb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"k",0.5,10)
e.ltype_prediction(1,15,1,False)
show(e.p)
# Out:
#     <div class="plotdiv" id="c6a0f89c-071b-4e02-afd0-89fe294e9c82"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"SVM",5,10)
e.ltype_prediction(1,4,5,True)
show(e.p)

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"RF",5,10)
e.ltype_prediction(1,10,10,False)
show(e.p)
# Out:
#     <div class="plotdiv" id="ed59ec17-0694-4276-be99-94ecacbe595f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"ANN",5,1)
e.ntype_prediction(1,3,50,True)
show(e.p)
# Out:
#     <div class="plotdiv" id="1fbb3616-f0f5-4bb9-ba96-387ab09f7df0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"ANN",5,1)
e.ntype_prediction(1,3,50,False)
show(e.p)
# Out:
#     <div class="plotdiv" id="a2aacba3-88f3-4cbc-852e-2e092013a830"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"ANN",5,1)
e.ltype_prediction(1,2,1,True)
show(e.p)
# Out:
# ---------------------------------------------------------------------------
# SocketError                               Traceback (most recent call last)
# <ipython-input-6-60f53091493d> in <module>()
#       1 e = composite_experiment([["cine","name","TMDb"],["inmaterial","Descripcion","EICH"],["wordnet","labelw3","WordNet"]],"ANN",5,1)
# ----> 2 e.ltype_prediction(1,2,1,True)
#       3 show(e.p)
#
# /home/pedro/node2vec/composite_experiment.pyc in ltype_prediction(self, a, b, jump, dev)
#      30         for idx,d in enumerate(self.ds):
#      31             e = experiment(d[0],7474,user,pswd,d[1],"normal",self.param,self.trainset_p,self.iteraciones)
# ---> 32             x,y,xd,yd = e.ltype_prediction(a,b,jump)
#      33             self.p.line(x, y, color=pal[idx],legend=d[2],line_width=2.0)
#      34             if(dev):
#
# /home/pedro/node2vec/experiment.pyc in ltype_prediction(self, a, b, jump)
# ...
